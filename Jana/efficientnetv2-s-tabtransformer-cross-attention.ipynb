# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_2801761.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0022925.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_8495841.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0015042.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0023502.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0014326.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_5093799.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0056156.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0066845.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0023300.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0060274.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_3568067.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0028933.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0021362.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0012818.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0066755.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_7412327.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0023398.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_9930718.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_9186977.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0019816.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_3297094.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_9004995.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_5626834.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0014123.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_1412871.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_3552245.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0013926.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_4110967.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_2001492.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0054024.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0057690.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0011239.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0070711.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_4949846.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0023504.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_6524119.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0064905.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0021048.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_5882793.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0028582.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0024019.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_9228573.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0015480.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0027742.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0003308.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0067733.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_7131359.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0010080.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0017411.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0030032.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0012112.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0033903.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_3152541.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0011892.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_1181483.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_9900876.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0015196.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0031479.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_8005770.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0802880.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0014291.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0031986.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_1857406.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0033624.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0064517.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0065918.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0015518.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_7480322.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0060104.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_5482648.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_8654660.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0029299.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0021376.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0033152.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0012736.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0021095.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0071095.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0066408.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0065746.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0031417.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_1571498.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0055556.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0011340.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0066539.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0012908.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_1948710.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0014190.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_1746873.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_5934354.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_1735950.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0067789.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_4282719.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0014078.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0010992.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0021257.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0021317.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0025037.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_2359366.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_5367118.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0071406.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0010719.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0023600.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_6562871.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0021693.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_7797655.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0025611.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0012125.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0014111.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0010396.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0069127.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0014030.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_6773367.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0021999.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0031059.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0027941.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0062339.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0023681.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_9939005.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0055280.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0023162.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0067444.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0014307.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0026352.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0013780.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0054819.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0026239.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0060511.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_2707375.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0022487.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0025595.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_5257528.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0058470.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_5107157.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0069889.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0024149.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0013402.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_7683106.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0022377.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_1200075.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0021530.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0023800.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_3976496.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0061685.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0021717.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0070400.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_7671776.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0072473.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0060406.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_7105988.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_7765349.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0022616.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0062103.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_7647299.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0022291.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_8243893.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_9097590.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0024007.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0065338.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0057089.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_3202358.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0010517.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0001104.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0055931.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0022941.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0072985.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0063425.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_3844971.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0058307.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0023423.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_9825516.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0022676.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_3015774.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_5567431.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_6821316.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0068383.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_8384985.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0023244.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_3182805.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_2553784.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_9955163.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0061194.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_3579477.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0069636.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0046405.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_1214018.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_6886000.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0024467.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0012830.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0065215.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_7751774.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0033239.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_6444362.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0066867.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0022707.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_3817719.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0053469.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0011039.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0012468.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_7588132.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_2768594.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0058332.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0022940.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0022348.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0017465.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_1464217.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_9060975.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_5134680.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_8635903.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0021702.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_3415401.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0070363.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0013487.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_5759661.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_8412921.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0011944.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0056130.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0011743.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_3541663.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_9556334.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0301568.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_1726444.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_1437062.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0071134.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_6563695.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0058869.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0058221.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0011495.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_7991784.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_3059347.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0022889.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0074311.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_2039831.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0069192.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0066830.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0056914.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0890398.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_6670764.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_3830607.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0013323.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0028075.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_6313487.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_6154038.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0012382.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0054312.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0017413.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0028520.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0033878.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_3535471.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0010135.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_7680659.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0067889.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_9933790.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0015154.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_8907509.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0063528.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0021520.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0029300.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_7164903.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_8751393.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0011605.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0011794.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0024511.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0023464.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0010296.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_1981133.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_1634173.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0425007.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0063199.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0022630.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0027100.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0952472.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_8157654.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0022999.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_5648155.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0013716.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0058766.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0061885.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0021110.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0011234.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0071707.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0022990.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0067805.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0029056.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0067601.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0021071.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0055546.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_7452515.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0011881.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0656566.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0013729.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0022812.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0014428.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_7378303.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_2052192.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0014228.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0063428.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0023714.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0010240.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_4462681.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0914168.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0058366.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_9488163.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0022370.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_1021252.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0031005.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0070120.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_1061502.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0066750.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0062112.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0057823.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0022556.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0059171.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0061281.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0011827.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_6361412.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_8023672.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0015297.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0060933.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0023642.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0056981.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0013815.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0015260.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_9185856.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0015073.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_7587078.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0022017.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_1177153.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0062029.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_3944634.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0030970.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0000404.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0022229.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_8894528.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_9163905.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0029034.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0065900.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_8423312.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0023322.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0068782.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_2800079.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0010817.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_5828787.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0012781.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0068881.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0062530.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0070006.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0013894.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0024663.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0022933.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_4390920.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0067006.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0023890.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0070410.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0022424.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_9229047.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_6981855.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0014344.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0010068.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0066617.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0014265.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0012571.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_5963113.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_7555839.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_4271377.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0053863.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0022013.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0056247.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0058580.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0036284.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0030809.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0011044.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0023674.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_4177450.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0032987.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_1990155.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0023369.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_2392633.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_3085118.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0022231.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0021550.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0030803.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0061735.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_1690499.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_3597597.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0032246.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0149698.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0001113.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0021509.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_5045552.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0013644.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0058164.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0055042.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0036095.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0027611.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0021799.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0021888.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0066213.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0220461.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0062172.jpg
# ...
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0033485.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0070618.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0021088.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0212931.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0033802.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0001151.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0281658.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0032466.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_2031479.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0483611.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0056796.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0014019.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_6047043.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0056092.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0015459.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_4038015.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0054151.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_4821309.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0012966.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_8969274.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_4358017.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_1163258.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_2364150.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_7056760.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_9995166.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_6243656.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0069154.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_1566428.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_2098084.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_6616671.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0000395.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_6810088.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0023606.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0034076.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0046331.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0059972.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0058026.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0012859.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0072976.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_7358625.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0059595.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0021726.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0534674.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_6899551.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_9756791.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0565120.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0275828.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0068255.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_4451735.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0065324.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0010716.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_9420341.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0013448.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0072360.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0010836.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_5286021.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_2256331.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0021329.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0000531.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_5203137.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_1542284.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0023653.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_7346994.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0011237.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0492483.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_5303069.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0000142.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0030474.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0069291.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_5801307.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0017412.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0013669.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_8119203.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0021312.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_7980143.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0000344.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0011788.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_3143255.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0063723.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0021666.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0073238.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0013264.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0015266.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0024868.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0068941.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0889205.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0015630.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0061936.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0021651.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0022996.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_4673844.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0016137.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0027822.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_7803118.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0022654.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0033470.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0011758.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_5086709.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_7836709.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0062639.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0056808.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0069705.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_3231840.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_1684127.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0010523.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0013955.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_8035370.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_2266290.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_9363532.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_7920705.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0014452.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0023836.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0058256.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_6904410.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_3139292.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0015231.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0070809.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_5350216.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_9959917.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_8959773.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0010839.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0014405.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_2670475.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0036159.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0072002.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_9280667.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_9107280.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0010408.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_9382025.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0026236.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_6581411.jpg
# /kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images/ISIC_0013123.jpg
# /kaggle/input/datasets/reemalasfar/final-csv/final_preprocessed_data.csv

# %%
# !pip install captum shap
# Out:
# Requirement already satisfied: captum in /usr/local/lib/python3.12/dist-packages (0.9.0)
# Requirement already satisfied: shap in /usr/local/lib/python3.12/dist-packages (0.50.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from captum) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from captum) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from captum) (26.0)
# Requirement already satisfied: torch>=2.3 in /usr/local/lib/python3.12/dist-packages (from captum) (2.10.0+cu128)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from captum) (4.67.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from shap) (1.16.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from shap) (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from shap) (2.3.3)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.12/dist-packages (from shap) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.12/dist-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from shap) (3.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from shap) (4.15.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.54->shap) (0.43.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.3->captum) (3.24.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.3->captum) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3->captum) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3->captum) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3->captum) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3->captum) (2026.2.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3->captum) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3->captum) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3->captum) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3->captum) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3->captum) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3->captum) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3->captum) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3->captum) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3->captum) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3->captum) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3->captum) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3->captum) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3->captum) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3->captum) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3->captum) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3->captum) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3->captum) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.3->captum) (1.3.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->captum) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->captum) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->captum) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->captum) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->captum) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->captum) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->captum) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->shap) (2025.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->shap) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->shap) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->captum) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.3->captum) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.3->captum) (3.0.3)

# %%
"""
╔══════════════════════════════════════════════════════════════════════════════╗
║   ISIC-DICM-17K — EfficientNetV2-S + TabTransformer + Cross-Attention       ║
║                 v2 FIXED  +  XAI SUITE (no SHAP)                            ║
╚══════════════════════════════════════════════════════════════════════════════╝

XAI methods in this cell:
  1. Grad-CAM++              — improved class heatmap
  2. Integrated Gradients    — pixel attribution  (image stream)
  3. Integrated Gradients    — feature attribution (tabular stream)
  4. Attention Rollout       — recursive attention across TabTransformer layers
  5. Raw Cross-Attention     — which clinical features focus where in the image

SHAP is in a SEPARATE cell — run it after training is done.

Install:
    # !pip install -q timm captum shap
"""

# ─── 0. Imports ───────────────────────────────────────────────────────────────
import os
import gc
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as mpl_cm
import seaborn as sns
from PIL import Image
from tqdm import tqdm
import warnings
warnings.filterwarnings("ignore")

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from torchvision import transforms
import timm
import re

from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import (
    roc_auc_score, classification_report,
    confusion_matrix, roc_curve, f1_score
)

from captum.attr import IntegratedGradients


# ─── 1. Configuration ─────────────────────────────────────────────────────────
class CFG:
    # ── Paths ─────────────────────────────────────────────────────────────────
    CSV_PATH   = "/kaggle/input/datasets/reemalasfar/final-csv/final_preprocessed_data.csv"
    IMAGES_DIR = "/kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images"
    OUTPUT_DIR = "/kaggle/working/efficient_v2_outputs/"

    # ── Column names ──────────────────────────────────────────────────────────
    IMG_COL    = "image"
    TARGET_COL = "class"

    DROP_COLS  = [
        "image", "isic_id", "patient_id", "class",
        "diagnosis_confirm_type_histopathology",
        "anatom_site_general_oral/genital",
        "age_group_0-20", "age_group_21-40",
        "age_group_41-60", "age_group_61-85",
        "year",
    ]

    # ── Image ─────────────────────────────────────────────────────────────────
    IMG_SIZE   = 384
    MEAN       = [0.485, 0.456, 0.406]
    STD        = [0.229, 0.224, 0.225]

    # ── Transformer dims ──────────────────────────────────────────────────────
    D             = 128
    NUM_HEADS     = 8
    FF_DIM        = 256
    NUM_CA_LAYERS = 2
    DROPOUT_TF    = 0.15

    # ── TabTransformer ────────────────────────────────────────────────────────
    TAB_DEPTH  = 2
    TAB_HEADS  = 4

    # ── EfficientNetV2-S backbone ─────────────────────────────────────────────
    EFF_MODEL     = "tf_efficientnetv2_s.in21k_ft_in1k"
    FREEZE_BLOCKS = 4

    # ── Training ──────────────────────────────────────────────────────────────
    SEED          = 42
    EPOCHS        = 30
    BATCH_SIZE    = 16
    GRAD_ACCUM    = 2
    NUM_WORKERS   = 2
    PATIENCE      = 10
    LABEL_SMOOTH  = 0.10

    # ── Focal Loss ────────────────────────────────────────────────────────────
    FOCAL_ALPHA   = 0.25
    FOCAL_GAMMA   = 2.0

    # ── Optimizer ─────────────────────────────────────────────────────────────
    LR_BACKBONE   = 2e-5
    LR_HEAD       = 2e-4
    WEIGHT_DECAY  = 1e-4
    WARMUP_EPOCHS = 3

    # ── Gradual unfreezing ────────────────────────────────────────────────────
    UNFREEZE_EPOCH_1 = 10
    UNFREEZE_EPOCH_2 = 20

    # ── EMA early stopping ────────────────────────────────────────────────────
    EMA_ALPHA     = 0.3

    # ── Augmentation mix ──────────────────────────────────────────────────────
    CUTMIX_PROB   = 0.30
    MIXUP_PROB    = 0.20
    CUTMIX_ALPHA  = 1.0
    MIXUP_ALPHA   = 0.4

    # ── TTA ───────────────────────────────────────────────────────────────────
    TTA_STEPS     = 5

    # ── K-Fold ────────────────────────────────────────────────────────────────
    USE_KFOLD  = False
    N_FOLDS    = 5

    # ── XAI (no SHAP here — SHAP is in the next cell) ────────────────────────
    XAI_N_SAMPLES       = 5     # number of val images to explain individually
    XAI_IG_STEPS        = 50    # Integrated Gradients interpolation steps

    DEVICE     = "cuda" if torch.cuda.is_available() else "cpu"


os.makedirs(CFG.OUTPUT_DIR, exist_ok=True)
torch.manual_seed(CFG.SEED)
np.random.seed(CFG.SEED)
print(f"Device : {CFG.DEVICE}")
print(f"GPU    : {torch.cuda.get_device_name(0) if CFG.DEVICE == 'cuda' else 'N/A'}")


# ─── 2. Feature Validator ─────────────────────────────────────────────────────
def validate_features(df, meta_cols):
    print("\n── Feature validation ──")
    issues = []
    for c in meta_cols:
        if df[c].std() == 0:
            issues.append(f"DEAD COLUMN (zero variance): {c}")
    for c in meta_cols:
        r = abs(df[c].corr(df[CFG.TARGET_COL]))
        if r > 0.45:
            issues.append(f"LEAKAGE RISK (r={r:.3f} with class): {c}")
    if issues:
        for i in issues:
            print(f"  {i}")
        raise ValueError("Fix issues above — add column names to CFG.DROP_COLS.")
    sparse = [(c, (df[c] == 0).mean()) for c in meta_cols
              if (df[c] == 0).mean() > 0.99]
    if sparse:
        print("  Sparse features (>99% zeros) — keeping as missing-data signal:")
        for c, pct in sparse:
            print(f"    {c} ({pct*100:.1f}% zeros)")
    print(f"  Passed — {len(meta_cols)} clean features ready for training.\n")


# ─── 3. EMA Tracker ───────────────────────────────────────────────────────────
class EMAMetric:
    def __init__(self, alpha=0.3):
        self.alpha = alpha
        self.value = None

    def update(self, v):
        self.value = v if self.value is None \
            else self.alpha * v + (1 - self.alpha) * self.value
        return self.value


# ─── 4. Threshold Optimizer ───────────────────────────────────────────────────
def find_optimal_threshold(labels, probs):
    fpr, tpr, thresholds = roc_curve(labels, probs)
    j        = tpr - fpr
    best_idx = int(np.argmax(j))
    return float(thresholds[best_idx]), float(j[best_idx])


# ─── 5. Dataset ───────────────────────────────────────────────────────────────
class ISICDataset(Dataset):
    def __init__(self, df, images_dir, augment=False):
        self.df         = df.reset_index(drop=True)
        self.images_dir = images_dir
        self.meta_cols  = [c for c in df.columns if c not in CFG.DROP_COLS]
        self.meta_dim   = len(self.meta_cols)
        self.augment    = augment

        if augment:
            self.transform = transforms.Compose([
                transforms.Resize((CFG.IMG_SIZE, CFG.IMG_SIZE)),
                transforms.RandomHorizontalFlip(p=0.5),
                transforms.RandomVerticalFlip(p=0.5),
                transforms.RandomRotation(degrees=30),
                transforms.ColorJitter(
                    brightness=0.3, contrast=0.3, saturation=0.3, hue=0.08,
                ),
                transforms.RandomGrayscale(p=0.1),
                transforms.GaussianBlur(kernel_size=5, sigma=(0.1, 1.5)),
                transforms.RandomAffine(
                    degrees=0, translate=(0.1, 0.1), scale=(0.9, 1.1)
                ),
                transforms.ToTensor(),
                transforms.Normalize(CFG.MEAN, CFG.STD),
                transforms.RandomErasing(p=0.2, scale=(0.02, 0.1)),
            ])
        else:
            self.transform = transforms.Compose([
                transforms.Resize((CFG.IMG_SIZE, CFG.IMG_SIZE)),
                transforms.ToTensor(),
                transforms.Normalize(CFG.MEAN, CFG.STD),
            ])

        self.tta_transforms = [
            transforms.Compose([
                transforms.Resize((CFG.IMG_SIZE, CFG.IMG_SIZE)),
                transforms.ToTensor(),
                transforms.Normalize(CFG.MEAN, CFG.STD),
            ]),
            transforms.Compose([
                transforms.Resize((CFG.IMG_SIZE, CFG.IMG_SIZE)),
                transforms.RandomHorizontalFlip(p=1.0),
                transforms.ToTensor(),
                transforms.Normalize(CFG.MEAN, CFG.STD),
            ]),
            transforms.Compose([
                transforms.Resize((CFG.IMG_SIZE, CFG.IMG_SIZE)),
                transforms.RandomVerticalFlip(p=1.0),
                transforms.ToTensor(),
                transforms.Normalize(CFG.MEAN, CFG.STD),
            ]),
            transforms.Compose([
                transforms.Resize((CFG.IMG_SIZE, CFG.IMG_SIZE)),
                transforms.RandomRotation(degrees=(90, 90)),
                transforms.ToTensor(),
                transforms.Normalize(CFG.MEAN, CFG.STD),
            ]),
            transforms.Compose([
                transforms.Resize((CFG.IMG_SIZE, CFG.IMG_SIZE)),
                transforms.RandomRotation(degrees=(270, 270)),
                transforms.ToTensor(),
                transforms.Normalize(CFG.MEAN, CFG.STD),
            ]),
        ]

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row      = self.df.iloc[idx]
        img_name = str(row[CFG.IMG_COL])
        img_path = os.path.join(self.images_dir, img_name)
        if not os.path.exists(img_path):
            raise FileNotFoundError(f"Missing: {img_path}")
        image = Image.open(img_path).convert("RGB")
        image = self.transform(image)
        meta  = torch.tensor(
            row[self.meta_cols].values.astype(np.float32),
            dtype=torch.float32
        )
        label = torch.tensor(int(row[CFG.TARGET_COL]), dtype=torch.long)
        return image, meta, label


def make_weighted_sampler(labels, epoch=0):
    class_counts  = np.bincount(labels)
    class_weights = 1.0 / class_counts
    sample_w      = class_weights[labels]
    return WeightedRandomSampler(
        weights=torch.from_numpy(sample_w).float(),
        num_samples=len(sample_w),
        replacement=True,
        generator=torch.Generator().manual_seed(CFG.SEED + epoch)
    )


# ─── 7. Augmentation Mix ──────────────────────────────────────────────────────
def cutmix_batch(images, labels, alpha=1.0):
    B        = images.size(0)
    lam      = np.random.beta(alpha, alpha)
    rand_idx = torch.randperm(B)
    W, H     = images.size(3), images.size(2)
    cut_w    = int(W * np.sqrt(1 - lam))
    cut_h    = int(H * np.sqrt(1 - lam))
    cx, cy   = np.random.randint(W), np.random.randint(H)
    x1 = max(cx - cut_w // 2, 0);  x2 = min(cx + cut_w // 2, W)
    y1 = max(cy - cut_h // 2, 0);  y2 = min(cy + cut_h // 2, H)
    images_m = images.clone()
    images_m[:, :, y1:y2, x1:x2] = images[rand_idx, :, y1:y2, x1:x2]
    lam = 1 - ((x2 - x1) * (y2 - y1)) / (W * H)
    return images_m, labels, labels[rand_idx], lam


def mixup_batch(images, labels, alpha=0.4):
    lam      = np.random.beta(alpha, alpha)
    rand_idx = torch.randperm(images.size(0))
    mixed    = lam * images + (1 - lam) * images[rand_idx]
    return mixed, labels, labels[rand_idx], lam


def apply_augmentation_mix(images, labels):
    rand = np.random.random()
    if rand < CFG.CUTMIX_PROB:
        images, la, lb, lam = cutmix_batch(images, labels, CFG.CUTMIX_ALPHA)
        return images, la, lb, lam, True
    elif rand < CFG.CUTMIX_PROB + CFG.MIXUP_PROB:
        images, la, lb, lam = mixup_batch(images, labels, CFG.MIXUP_ALPHA)
        return images, la, lb, lam, True
    else:
        return images, labels, labels, 1.0, False


# ─── 8. Model Components ──────────────────────────────────────────────────────

class EfficientNetV2Encoder(nn.Module):
    def __init__(self, out_dim=128, dropout=0.15):
        super().__init__()
        self.backbone = timm.create_model(
            CFG.EFF_MODEL,
            pretrained=True,
            num_classes=0,
            global_pool="",
        )
        self._freeze_blocks(CFG.FREEZE_BLOCKS)

        with torch.no_grad():
            dummy         = torch.zeros(1, 3, CFG.IMG_SIZE, CFG.IMG_SIZE)
            feats         = self.backbone(dummy)
            self.feat_dim = feats.shape[1]
            self.feat_h   = feats.shape[2]
            self.feat_w   = feats.shape[3]
            print(f"  EfficientNetV2-S feature map: "
                  f"{self.feat_dim}×{self.feat_h}×{self.feat_w} "
                  f"→ {self.feat_h * self.feat_w} spatial tokens")

        self.proj = nn.Sequential(
            nn.Conv2d(self.feat_dim, out_dim, kernel_size=1, bias=False),
            nn.BatchNorm2d(out_dim),
            nn.GELU(),
            nn.Dropout2d(dropout),
        )
        n_patches    = self.feat_h * self.feat_w
        self.pos_emb = nn.Parameter(torch.zeros(1, n_patches, out_dim))
        nn.init.trunc_normal_(self.pos_emb, std=0.02)
        self.cls_token = nn.Parameter(torch.zeros(1, 1, out_dim))
        nn.init.trunc_normal_(self.cls_token, std=0.02)

    def _freeze_blocks(self, n_freeze):
        for param in self.backbone.conv_stem.parameters():
            param.requires_grad = False
        for param in self.backbone.bn1.parameters():
            param.requires_grad = False
        for i in range(n_freeze):
            for name, param in self.backbone.named_parameters():
                if name.startswith(f"blocks.{i}."):
                    param.requires_grad = False

    def unfreeze_blocks(self, from_block, to_block):
        for i in range(from_block, to_block):
            for name, param in self.backbone.named_parameters():
                if name.startswith(f"blocks.{i}."):
                    param.requires_grad = True
        trainable = sum(p.numel() for p in self.backbone.parameters()
                        if p.requires_grad)
        print(f"  🔓 Unfroze blocks {from_block}–{to_block-1} | "
              f"Backbone trainable params: {trainable:,}")

    def get_newly_unfrozen_params(self, from_block, to_block):
        params = []
        for i in range(from_block, to_block):
            for name, param in self.backbone.named_parameters():
                if name.startswith(f"blocks.{i}.") and param.requires_grad:
                    params.append(param)
        return params

    def forward(self, x):
        feats  = self.backbone(x)
        tokens = self.proj(feats)
        B, D, H, W = tokens.shape
        tokens = tokens.flatten(2).transpose(1, 2)
        tokens = tokens + self.pos_emb
        cls    = self.cls_token.expand(B, -1, -1)
        return torch.cat([cls, tokens], dim=1)


class TabTransformerEncoder(nn.Module):
    def __init__(self, num_features, embed_dim=128, depth=2,
                 num_heads=4, ff_dim=256, dropout=0.15):
        super().__init__()
        self.num_features = num_features
        self.feature_embeddings = nn.ModuleList([
            nn.Sequential(nn.Linear(1, embed_dim), nn.LayerNorm(embed_dim))
            for _ in range(num_features)
        ])
        self.pos_emb   = nn.Parameter(torch.zeros(1, num_features, embed_dim))
        self.cls_token = nn.Parameter(torch.zeros(1, 1, embed_dim))
        nn.init.trunc_normal_(self.pos_emb,   std=0.02)
        nn.init.trunc_normal_(self.cls_token, std=0.02)
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=embed_dim, nhead=num_heads,
            dim_feedforward=ff_dim, dropout=dropout,
            activation="gelu", batch_first=True, norm_first=True
        )
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=depth)
        self.norm        = nn.LayerNorm(embed_dim)

    def forward(self, x):
        B      = x.size(0)
        tokens = torch.stack([
            self.feature_embeddings[i](x[:, i:i+1])
            for i in range(self.num_features)
        ], dim=1)
        tokens = tokens + self.pos_emb
        cls    = self.cls_token.expand(B, -1, -1)
        tokens = torch.cat([cls, tokens], dim=1)
        tokens = self.transformer(tokens)
        return self.norm(tokens)


class CrossAttentionBlock(nn.Module):
    def __init__(self, dim, num_heads, ff_dim, dropout=0.15):
        super().__init__()
        self.meta_to_img = nn.MultiheadAttention(
            embed_dim=dim, num_heads=num_heads,
            dropout=dropout, batch_first=True
        )
        self.ffn_meta = nn.Sequential(
            nn.LayerNorm(dim), nn.Linear(dim, ff_dim),
            nn.GELU(), nn.Dropout(dropout),
            nn.Linear(ff_dim, dim), nn.Dropout(dropout),
        )
        self.img_self_attn = nn.MultiheadAttention(
            embed_dim=dim, num_heads=num_heads,
            dropout=dropout, batch_first=True
        )
        self.ffn_img = nn.Sequential(
            nn.LayerNorm(dim), nn.Linear(dim, ff_dim),
            nn.GELU(), nn.Dropout(dropout),
            nn.Linear(ff_dim, dim), nn.Dropout(dropout),
        )
        self.norm_img  = nn.LayerNorm(dim)
        self.norm_meta = nn.LayerNorm(dim)

    def forward(self, img_tokens, meta_tokens):
        img_sa, _ = self.img_self_attn(
            query=self.norm_img(img_tokens),
            key=img_tokens, value=img_tokens,
            need_weights=False
        )
        img_tokens  = img_tokens + img_sa
        img_tokens  = img_tokens + self.ffn_img(img_tokens)
        meta_ca, attn_weights = self.meta_to_img(
            query=self.norm_meta(meta_tokens),
            key=img_tokens, value=img_tokens,
            need_weights=True, average_attn_weights=False
        )
        meta_tokens = meta_tokens + meta_ca
        meta_tokens = meta_tokens + self.ffn_meta(meta_tokens)
        return img_tokens, meta_tokens, attn_weights


class EfficientFusionModel(nn.Module):
    def __init__(self, meta_dim):
        super().__init__()
        D = CFG.D
        self.img_encoder  = EfficientNetV2Encoder(out_dim=D, dropout=CFG.DROPOUT_TF)
        self.meta_encoder = TabTransformerEncoder(
            num_features=meta_dim, embed_dim=D,
            depth=CFG.TAB_DEPTH, num_heads=CFG.TAB_HEADS,
            ff_dim=CFG.FF_DIM, dropout=CFG.DROPOUT_TF
        )
        self.ca_layers = nn.ModuleList([
            CrossAttentionBlock(
                dim=D, num_heads=CFG.NUM_HEADS,
                ff_dim=CFG.FF_DIM, dropout=CFG.DROPOUT_TF
            )
            for _ in range(CFG.NUM_CA_LAYERS)
        ])
        self.classifier = nn.Sequential(
            nn.LayerNorm(D * 2),
            nn.Linear(D * 2, 256),
            nn.GELU(), nn.Dropout(0.4),
            nn.Linear(256, 128),
            nn.GELU(), nn.Dropout(0.2),
            nn.Linear(128, 2),
        )
        self._attn_weights = None

    def forward(self, image, meta):
        img_tokens  = self.img_encoder(image)
        meta_tokens = self.meta_encoder(meta)
        for ca in self.ca_layers:
            img_tokens, meta_tokens, attn = ca(img_tokens, meta_tokens)
        self._attn_weights = attn.detach()
        img_cls  = img_tokens[:, 0, :]
        meta_cls = meta_tokens[:, 0, :]
        fused    = torch.cat([img_cls, meta_cls], dim=1)
        return self.classifier(fused)

    def get_attention_weights(self):
        return self._attn_weights

    def unfreeze_backbone_blocks(self, from_block, to_block):
        self.img_encoder.unfreeze_blocks(from_block, to_block)

    def get_newly_unfrozen_params(self, from_block, to_block):
        return self.img_encoder.get_newly_unfrozen_params(from_block, to_block)


# ─── 9. Loss Functions ────────────────────────────────────────────────────────
class FocalLoss(nn.Module):
    def __init__(self, alpha=0.25, gamma=2.0, smoothing=0.05):
        super().__init__()
        self.alpha     = alpha
        self.gamma     = gamma
        self.smoothing = smoothing

    def forward(self, logits, targets):
        n  = logits.size(1)
        lp = F.log_softmax(logits, dim=1)
        with torch.no_grad():
            s = torch.full_like(lp, self.smoothing / (n - 1))
            s.scatter_(1, targets.unsqueeze(1), 1.0 - self.smoothing)
        ce   = -(s * lp).sum(dim=1)
        pt   = torch.exp(-ce)
        loss = self.alpha * (1 - pt) ** self.gamma * ce
        return loss.mean()


class MixLoss(nn.Module):
    def __init__(self, alpha=0.25, gamma=2.0, smoothing=0.05):
        super().__init__()
        self.focal = FocalLoss(alpha, gamma, smoothing)

    def forward(self, logits, targets_a, targets_b=None, lam=1.0):
        if targets_b is None or lam == 1.0:
            return self.focal(logits, targets_a)
        return lam * self.focal(logits, targets_a) + \
               (1 - lam) * self.focal(logits, targets_b)


# ─── 10. LR Scheduler ─────────────────────────────────────────────────────────
class WarmupCosineScheduler:
    def __init__(self, optimizer, warmup_epochs, total_epochs, min_lr=1e-6):
        self.opt           = optimizer
        self.warmup_epochs = warmup_epochs
        self.total_epochs  = total_epochs
        self.min_lr        = min_lr
        self.base_lrs      = [pg["lr"] for pg in optimizer.param_groups]
        self._current_epoch = 0

    def add_new_param_group(self, lr):
        self.base_lrs.append(lr)

    def step(self, epoch):
        self._current_epoch = epoch
        e = epoch - 1
        if e < self.warmup_epochs:
            scale = max(0.01, (e + 1) / self.warmup_epochs)
        else:
            progress  = (e - self.warmup_epochs) / \
                        max(1, self.total_epochs - self.warmup_epochs)
            min_scale = self.min_lr / max(self.base_lrs)
            scale     = max(
                0.5 * (1 + math.cos(math.pi * progress)),
                min_scale
            )
        for pg, base in zip(self.opt.param_groups, self.base_lrs):
            pg["lr"] = base * scale

    def get_lr(self):
        return [pg["lr"] for pg in self.opt.param_groups]


# ─── 11. Train / Eval Loops ───────────────────────────────────────────────────
def train_one_epoch(model, loader, optimizer, criterion, scaler_amp, device):
    model.train()
    total_loss = 0
    all_labels, all_probs = [], []
    optimizer.zero_grad()

    for step, (images, metas, labels) in enumerate(
            tqdm(loader, desc="  Train", leave=False)):

        images = images.to(device, non_blocking=True)
        metas  = metas.to(device,  non_blocking=True)
        labels = labels.to(device, non_blocking=True)

        images, labels_a, labels_b, lam, use_mix = \
            apply_augmentation_mix(images, labels)

        with torch.amp.autocast("cuda", enabled=(device == "cuda")):
            logits = model(images, metas)
            loss   = criterion(logits, labels_a, labels_b if use_mix else None, lam) \
                     / CFG.GRAD_ACCUM

        scaler_amp.scale(loss).backward()

        if (step + 1) % CFG.GRAD_ACCUM == 0:
            scaler_amp.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=0.5)
            scaler_amp.step(optimizer)
            scaler_amp.update()
            optimizer.zero_grad()

        total_loss += loss.item() * CFG.GRAD_ACCUM * images.size(0)
        probs = torch.softmax(logits, dim=1)[:, 1].detach().float().cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels_a.cpu().numpy())

    avg_loss = total_loss / len(loader.dataset)
    auc      = roc_auc_score(all_labels, all_probs)
    return avg_loss, auc


@torch.no_grad()
def evaluate(model, loader, criterion, device, threshold=0.5):
    model.eval()
    total_loss = 0
    all_labels, all_probs, all_preds = [], [], []

    for images, metas, labels in tqdm(loader, desc="  Val  ", leave=False):
        images = images.to(device, non_blocking=True)
        metas  = metas.to(device,  non_blocking=True)
        labels = labels.to(device, non_blocking=True)
        with torch.amp.autocast("cuda", enabled=(device == "cuda")):
            logits = model(images, metas)
            loss   = criterion(logits, labels)
        total_loss += loss.item() * images.size(0)
        probs  = torch.softmax(logits, dim=1)[:, 1].float().cpu().numpy()
        preds  = (probs >= threshold).astype(int)
        all_probs.extend(probs)
        all_preds.extend(preds)
        all_labels.extend(labels.cpu().numpy())

    avg_loss  = total_loss / len(loader.dataset)
    labels_np = np.array(all_labels)
    probs_np  = np.array(all_probs)
    preds_np  = np.array(all_preds)
    auc       = roc_auc_score(labels_np, probs_np)
    f1        = f1_score(labels_np, preds_np, average="macro")
    return avg_loss, auc, f1, labels_np, preds_np, probs_np


@torch.no_grad()
def evaluate_with_tta(model, dataset, criterion, device, threshold=0.5):
    model.eval()
    all_labels, all_probs = [], []
    loader = DataLoader(dataset, batch_size=CFG.BATCH_SIZE, shuffle=False,
                        num_workers=CFG.NUM_WORKERS, pin_memory=True)
    print("  Running TTA inference...")
    for tta_idx, tta_tf in enumerate(dataset.tta_transforms):
        dataset.transform = tta_tf
        tta_probs = []
        for images, metas, labels in tqdm(
                loader,
                desc=f"  TTA {tta_idx+1}/{len(dataset.tta_transforms)}",
                leave=False):
            images = images.to(device, non_blocking=True)
            metas  = metas.to(device,  non_blocking=True)
            with torch.amp.autocast("cuda", enabled=(device == "cuda")):
                logits = model(images, metas)
            probs  = torch.softmax(logits, dim=1)[:, 1].float().cpu().numpy()
            tta_probs.extend(probs)
            if tta_idx == 0:
                all_labels.extend(labels.numpy())
        all_probs.append(np.array(tta_probs))
    dataset.transform = dataset.tta_transforms[0]
    avg_probs = np.mean(all_probs, axis=0)
    labels_np = np.array(all_labels)
    auc       = roc_auc_score(labels_np, avg_probs)
    preds_np  = (avg_probs >= threshold).astype(int)
    f1        = f1_score(labels_np, preds_np, average="macro")
    print(f"  TTA AUC: {auc:.4f}  F1: {f1:.4f}")
    return auc, f1, labels_np, preds_np, avg_probs


# ─── 12. Plot Helpers ─────────────────────────────────────────────────────────
def plot_training_curves(history, fold=None):
    tag = f"_fold{fold}" if fold else ""
    fig, axes = plt.subplots(1, 4, figsize=(22, 5))
    axes[0].plot(history["train_loss"], label="Train", marker="o", ms=3)
    axes[0].plot(history["val_loss"],   label="Val",   marker="o", ms=3)
    axes[0].set_title("Focal Loss"); axes[0].legend(); axes[0].grid(True)
    axes[1].plot(history["train_auc"],   label="Train raw",  ms=3, alpha=0.4)
    axes[1].plot(history["val_auc"],     label="Val raw",    ms=3, alpha=0.4)
    axes[1].plot(history["val_auc_ema"], label="Val EMA", lw=2)
    axes[1].set_title("AUC-ROC"); axes[1].legend(); axes[1].grid(True)
    axes[2].plot(history["val_f1"], label="Val F1", color="green", ms=3)
    axes[2].set_title("Val F1 macro"); axes[2].legend(); axes[2].grid(True)
    axes[3].plot(history["threshold"], label="Youden-J threshold", color="purple", ms=3)
    axes[3].axhline(0.5, color="gray", linestyle="--", alpha=0.5, label="Default 0.5")
    axes[3].set_title("Optimal threshold"); axes[3].legend(); axes[3].grid(True)
    plt.suptitle(
        f"EfficientNetV2-S × TabTransformer v2-Fixed"
        f"{' | Fold '+str(fold) if fold else ''}",
        fontsize=13, fontweight="bold"
    )
    plt.tight_layout()
    path = os.path.join(CFG.OUTPUT_DIR, f"training_curves_efficient_v2{tag}.png")
    plt.savefig(path, dpi=150); plt.show(); plt.close()
    print(f"Saved: {path}")


def plot_confusion_matrix(labels, preds, threshold, fold=None):
    tag = f"_fold{fold}" if fold else ""
    cm  = confusion_matrix(labels, preds)
    fig, ax = plt.subplots(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                xticklabels=["Non-Melanoma", "Melanoma"],
                yticklabels=["Non-Melanoma", "Melanoma"], ax=ax)
    ax.set_ylabel("True"); ax.set_xlabel("Predicted")
    ax.set_title(f"Confusion Matrix (threshold={threshold:.3f})")
    plt.tight_layout()
    path = os.path.join(CFG.OUTPUT_DIR, f"confusion_matrix_efficient_v2{tag}.png")
    plt.savefig(path, dpi=150); plt.show(); plt.close()


def plot_roc_curve(labels, probs, auc_score, threshold, fold=None):
    tag = f"_fold{fold}" if fold else ""
    fpr, tpr, _ = roc_curve(labels, probs)
    fig, ax = plt.subplots(figsize=(6, 5))
    ax.plot(fpr, tpr, lw=2, color="steelblue", label=f"AUC = {auc_score:.4f}")
    ax.plot([0, 1], [0, 1], "k--")
    ax.set_xlabel("FPR"); ax.set_ylabel("TPR")
    ax.set_title(f"ROC Curve (optimal threshold={threshold:.3f})")
    ax.legend(); ax.grid(True)
    plt.tight_layout()
    path = os.path.join(CFG.OUTPUT_DIR, f"roc_curve_efficient_v2{tag}.png")
    plt.savefig(path, dpi=150); plt.show(); plt.close()


# ─── 13. XAI Shared Helpers ───────────────────────────────────────────────────

_XAI_TF = transforms.Compose([
    transforms.Resize((CFG.IMG_SIZE, CFG.IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(CFG.MEAN, CFG.STD),
])

def _norm01(x):
    mn, mx = x.min(), x.max()
    return (x - mn) / (mx - mn + 1e-8)

def _resize_map(arr2d, size):
    pil = Image.fromarray((_norm01(arr2d) * 255).astype(np.uint8))
    return np.array(pil.resize((size, size), Image.BILINEAR)) / 255.0

def _overlay(rgb, heatmap, alpha=0.5):
    colored = mpl_cm.get_cmap("jet")(heatmap)[..., :3]
    return np.clip((1 - alpha) * rgb + alpha * colored, 0, 1)

def _save(fig, name):
    path = os.path.join(CFG.OUTPUT_DIR, name)
    fig.savefig(path, dpi=150, bbox_inches="tight")
    plt.show()
    plt.close(fig)
    print(f"  ✔ {path}")

def _xai_load_from_path(img_path_or_name, meta_series):
    """
    Robustly find the image and load tensors. 
    Handles both full paths and raw CSV filenames.
    """
    # 1. Standardize the filename using regex
    raw_name = str(img_path_or_name).split('/')[-1] # Get just the filename
    match = re.search(r'(\d{7})', raw_name)
    clean_name = f"ISIC_{match.group(1)}.jpg" if match else raw_name
    
    # 2. Build the final path
    final_path = os.path.join(CFG.IMAGES_DIR, clean_name)
    
    if not os.path.exists(final_path):
        raise FileNotFoundError(f"XAI could not find image: {final_path}")
        
    img = Image.open(final_path).convert("RGB")
    it  = _XAI_TF(img).unsqueeze(0).to(CFG.DEVICE)
    # Ensure we only take values that are actually numeric
    # Ensure we only take values that are actually numeric
    mt = torch.tensor(meta_series.values.astype(np.float32), dtype=torch.float32).unsqueeze(0).to(CFG.DEVICE)
    rgb = it.squeeze().cpu().permute(1, 2, 0).numpy() * np.array(CFG.STD) + np.array(CFG.MEAN)
    return it, mt, np.clip(rgb, 0, 1)


# ─── 14. XAI Method 1 & 2: Grad-CAM and Grad-CAM++ ──────────────────────────

def _get_last_conv(model):
    last = None
    for m in model.img_encoder.backbone.modules():
        if isinstance(m, nn.Conv2d):
            last = m
    return last


class _GradCAMEngine:
    def __init__(self, model, plus_plus=False):
        self.model     = model
        self.plus_plus = plus_plus
        self._acts     = None
        self._grads    = None
        tl = _get_last_conv(model)
        self._fh = tl.register_forward_hook(
            lambda m, i, o: setattr(self, "_acts", o.detach())
        )
        self._bh = tl.register_full_backward_hook(
            lambda m, gi, go: setattr(self, "_grads", go[0].detach())
        )

    def remove(self):
        self._fh.remove()
        self._bh.remove()

    def __call__(self, img_t, meta_t, class_idx=1):
        self.model.zero_grad()
        logits = self.model(img_t, meta_t)
        logits[0, class_idx].backward()
        g = self._grads
        a = self._acts

        if self.plus_plus:
            g2    = g ** 2
            g3    = g ** 3
            denom = 2 * g2 + g3 * a.sum(dim=(2, 3), keepdim=True) + 1e-8
            alpha = g2 / denom
            w     = (alpha * F.relu(g)).sum(dim=(2, 3), keepdim=True)
        else:
            w = g.mean(dim=(2, 3), keepdim=True)

        cam = F.relu((w * a).sum(dim=1).squeeze())
        return _norm01(cam.cpu().numpy())


def xai_gradcam_pp(model, img_t, meta_t, rgb, meta_cols_used,
                   save_tag="", class_idx=1):
    S = rgb.shape[0]

    gc_eng  = _GradCAMEngine(model, plus_plus=False)
    gc_map  = gc_eng(img_t.clone(), meta_t.clone(), class_idx)
    gc_eng.remove()

    pp_eng  = _GradCAMEngine(model, plus_plus=True)
    pp_map  = pp_eng(img_t.clone(), meta_t.clone(), class_idx)
    pp_eng.remove()

    fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    axes[0].imshow(rgb);                                        axes[0].set_title("Original image")
    axes[1].imshow(_overlay(rgb, _resize_map(gc_map, S)));      axes[1].set_title("Grad-CAM")
    axes[2].imshow(_overlay(rgb, _resize_map(pp_map, S)));      axes[2].set_title("Grad-CAM++")
    for ax in axes: ax.axis("off")

    with torch.no_grad():
        prob = torch.softmax(model(img_t, meta_t), dim=1)[0, class_idx].item()
    fig.suptitle(f"Grad-CAM family  |  P(Melanoma) = {prob:.3f}",
                 fontsize=13, fontweight="bold")
    plt.tight_layout()
    _save(fig, f"xai_gradcam{save_tag}.png")
    return gc_map, pp_map


# ─── 15. XAI Method 3: Integrated Gradients ──────────────────────────────────

def xai_integrated_gradients(model, img_t, meta_t, rgb, meta_cols_used,
                               save_tag="", class_idx=1, n_steps=None):
    if n_steps is None:
        n_steps = CFG.XAI_IG_STEPS

    S      = rgb.shape[0]
    ig_eng = IntegratedGradients(model)

    model.zero_grad()
    attr, delta = ig_eng.attribute(
        inputs    = (img_t, meta_t),
        baselines = (torch.zeros_like(img_t), torch.zeros_like(meta_t)),
        target    = class_idx,
        n_steps   = n_steps,
        return_convergence_delta=True,
    )

    img_attr = attr[0].squeeze().permute(1, 2, 0).cpu().numpy()
    img_map  = _norm01(np.abs(img_attr).sum(axis=-1))
    tab_attr = attr[1].squeeze().cpu().numpy()
    n_feat   = len(meta_cols_used)

    fig = plt.figure(figsize=(18, 6))
    gs  = fig.add_gridspec(1, 3, width_ratios=[1, 1, 1.4])
    ax0 = fig.add_subplot(gs[0])
    ax1 = fig.add_subplot(gs[1])
    ax2 = fig.add_subplot(gs[2])

    ax0.imshow(rgb);  ax0.axis("off");  ax0.set_title("Original image")

    ax1.imshow(_overlay(rgb, _resize_map(img_map, S)))
    ax1.axis("off")
    ax1.set_title(f"IG — image attribution\n(convergence Δ={delta.item():.3f})")

    top_k   = min(20, n_feat)
    order   = np.argsort(np.abs(tab_attr))[::-1][:top_k]
    vals    = tab_attr[order][::-1]
    names   = [meta_cols_used[i] for i in order][::-1]
    colors  = ["#d6604d" if v > 0 else "#4393c3" for v in vals]
    ax2.barh(range(top_k), vals, color=colors)
    ax2.set_yticks(range(top_k))
    ax2.set_yticklabels(names, fontsize=8)
    ax2.axvline(0, color="black", lw=0.8)
    ax2.set_title("IG — tabular attribution\n(red=↑ melanoma, blue=↓ melanoma)")
    ax2.grid(axis="x", alpha=0.3)

    with torch.no_grad():
        prob = torch.softmax(model(img_t, meta_t), dim=1)[0, class_idx].item()
    fig.suptitle(f"Integrated Gradients (multimodal)  |  P(Melanoma) = {prob:.3f}",
                 fontsize=13, fontweight="bold")
    plt.tight_layout()
    _save(fig, f"xai_integrated_gradients{save_tag}.png")
    return img_attr, tab_attr


# ─── 16. XAI Method 4: Attention Rollout + Cross-Attention ───────────────────

def xai_attention_rollout(model, img_t, meta_t, rgb, meta_cols_used,
                           feat_h, feat_w, save_tag=""):
    S     = rgb.shape[0]
    store = {}
    hooks = []

    def _make_hook(name):
        def _h(module, inp, out):
            if isinstance(out, tuple) and len(out) >= 2 and out[1] is not None:
                store[name] = out[1].detach().cpu().float()
        return _h

    for i, layer in enumerate(model.meta_encoder.transformer.layers):
        hooks.append(
            layer.self_attn.register_forward_hook(_make_hook(f"tab_sa_{i}"))
        )
    last_ca = model.ca_layers[-1]
    hooks.append(
        last_ca.meta_to_img.register_forward_hook(_make_hook("cross_attn"))
    )

    with torch.no_grad():
        model(img_t, meta_t)
    for h in hooks:
        h.remove()

    sa_keys = sorted(k for k in store if k.startswith("tab_sa_"))
    rollout = None
    for k in sa_keys:
        attn = store[k][0]
        attn = attn.mean(dim=0)
        I    = torch.eye(attn.shape[0])
        attn = (attn + I)
        attn = attn / (attn.sum(dim=-1, keepdim=True) + 1e-8)
        rollout = attn if rollout is None else torch.matmul(attn, rollout)

    n_meta = len(meta_cols_used)

    cross_overlay = None
    if "cross_attn" in store:
        ca = store["cross_attn"][0]
        ca = ca.mean(dim=0)
        n_patches      = feat_h * feat_w
        patch_attn_row = ca[1:, 1:n_patches + 1]
        patch_attn_avg = patch_attn_row.mean(dim=0).numpy()
        if len(patch_attn_avg) == feat_h * feat_w:
            spatial    = patch_attn_avg.reshape(feat_h, feat_w)
        else:
            spatial    = np.zeros(feat_h * feat_w)
            spatial[:len(patch_attn_avg)] = patch_attn_avg
            spatial    = spatial.reshape(feat_h, feat_w)
        cross_overlay = _resize_map(spatial, S)

    fig, axes = plt.subplots(1, 3, figsize=(21, 6))

    if rollout is not None:
        n_show = min(rollout.shape[0], n_meta + 1)
        mat    = rollout[:n_show, :n_show].numpy()
        im     = axes[0].imshow(mat, cmap="Blues", aspect="auto")
        ticks  = ["CLS"] + list(meta_cols_used[:n_show - 1])
        axes[0].set_xticks(range(n_show))
        axes[0].set_yticks(range(n_show))
        axes[0].set_xticklabels(ticks, rotation=90, fontsize=7)
        axes[0].set_yticklabels(ticks, fontsize=7)
        plt.colorbar(im, ax=axes[0], fraction=0.046)
        axes[0].set_title("Attention Rollout\nTabTransformer (token × token)", fontsize=10)
    else:
        axes[0].axis("off")
        axes[0].set_title("Rollout unavailable")

    if rollout is not None and rollout.shape[0] > 1:
        cls_feat = rollout[0, 1:n_meta + 1].numpy()
        colors2  = mpl_cm.viridis(cls_feat / (cls_feat.max() + 1e-8))
        axes[1].bar(range(n_meta), cls_feat, color=colors2)
        axes[1].set_xticks(range(n_meta))
        axes[1].set_xticklabels(meta_cols_used, rotation=90, fontsize=7)
        axes[1].set_title("CLS → feature attention\n(how much CLS attends to each feature)", fontsize=10)
        axes[1].grid(axis="y", alpha=0.3)
    else:
        axes[1].axis("off")

    if cross_overlay is not None:
        axes[2].imshow(_overlay(rgb, cross_overlay, alpha=0.55))
        axes[2].set_title("Cross-Attention overlay\n(clinical features → image patches)", fontsize=10)
    else:
        axes[2].imshow(rgb)
        axes[2].set_title("Cross-attention unavailable")
    axes[2].axis("off")

    fig.suptitle("Attention Rollout + Cross-Attention Analysis",
                 fontsize=13, fontweight="bold")
    plt.tight_layout()
    _save(fig, f"xai_attention_rollout{save_tag}.png")
    return rollout, cross_overlay


# ─── 17. XAI Orchestrator (no SHAP) ──────────────────────────────────────────

def run_all_xai(model, val_df, meta_cols_used, feat_h, feat_w, fold=None):
    """
    Entry point for per-sample XAI. Called automatically at the end of run_training().

    Runs Grad-CAM, Grad-CAM++, Integrated Gradients (multimodal),
    Attention Rollout, and Cross-Attention for CFG.XAI_N_SAMPLES images.

    SHAP is intentionally excluded — run it in the next cell.
    """
    tag_fold = f"_fold{fold}" if fold else ""
    print(f"\n{'═'*65}")
    print(f"  XAI Suite  ({'Fold '+str(fold) if fold else 'Single run'})")
    print(f"  Methods: Grad-CAM, Grad-CAM++, Integrated Gradients (multimodal),")
    print(f"           Attention Rollout, Cross-Attention")
    print(f"  NOTE: SHAP runs in the NEXT cell — run it separately.")
    print(f"  Samples : {CFG.XAI_N_SAMPLES} individual")
    print(f"{'═'*65}\n")

    model.eval()

    # ── Pick samples: try to balance classes ──────────────────────────────────
    half    = CFG.XAI_N_SAMPLES // 2
    mel     = val_df[val_df[CFG.TARGET_COL] == 1].sample(
                  min(half + 1, (val_df[CFG.TARGET_COL] == 1).sum()),
                  random_state=CFG.SEED)
    non_mel = val_df[val_df[CFG.TARGET_COL] == 0].sample(
                  min(half, (val_df[CFG.TARGET_COL] == 0).sum()),
                  random_state=CFG.SEED)
    samples = pd.concat([mel, non_mel]).sample(frac=1, random_state=CFG.SEED)
    samples = samples.head(CFG.XAI_N_SAMPLES)

    for i, (_, row) in enumerate(samples.iterrows()):
        tag      = f"{tag_fold}_s{i+1}"
        true_lbl = int(row[CFG.TARGET_COL])
        meta_row = row[meta_cols_used]

        print(f"\n  ── Sample {i+1}/{CFG.XAI_N_SAMPLES}  "
              f"({'Melanoma' if true_lbl == 1 else 'Non-Melanoma'}) ──")

        # Soft-skip: regex cleaning + existence check both happen inside
        # _xai_load_from_path, so a single dirty/missing name never
        # kills the remaining samples or the 40-epoch training run.
        try:
            img_t, meta_t, rgb = _xai_load_from_path(
                str(row[CFG.IMG_COL]), meta_row
            )
        except FileNotFoundError as e:
            print(f"  Sample {i+1}: {e} — skipping.")
            continue

        xai_gradcam_pp(model, img_t, meta_t, rgb, meta_cols_used,
                       save_tag=tag)

        xai_integrated_gradients(model, img_t, meta_t, rgb, meta_cols_used,
                                  save_tag=tag)

        xai_attention_rollout(model, img_t, meta_t, rgb, meta_cols_used,
                               feat_h, feat_w, save_tag=tag)

        gc.collect()
        if CFG.DEVICE == "cuda":
            torch.cuda.empty_cache()

    print(f"\n  ✅ Per-sample XAI outputs saved to: {CFG.OUTPUT_DIR}")
    print(f"  ▶  Now run the SHAP cell below for global feature importance.")

# ─── 18. Original Attention Plots ─────────────────────────────────────────────
def plot_attention_heatmap(attn_weights, meta_cols, sample_idx=0, save_path=None):
    attn         = attn_weights[sample_idx].mean(dim=0)
    feature_attn = attn[1:, 1:].mean(dim=1).cpu().numpy()
    n      = min(len(meta_cols), len(feature_attn))
    vals   = feature_attn[:n]
    cols   = meta_cols[:n]
    colors = plt.cm.RdYlBu_r(vals / (vals.max() + 1e-8))
    fig, ax = plt.subplots(figsize=(max(14, n // 2), 3))
    ax.bar(range(n), vals, color=colors)
    ax.set_xticks(range(n))
    ax.set_xticklabels(cols, rotation=45, ha="right", fontsize=8)
    ax.set_ylabel("Attention weight (avg over image patches)")
    ax.set_title(
        "Cross-Attention: Clinical features → Image patches\n"
        "(How much does each clinical feature use visual information?)"
    )
    ax.grid(axis="y", alpha=0.3)
    plt.tight_layout()
    if save_path:
        plt.savefig(save_path, dpi=150, bbox_inches="tight")
    plt.show(); plt.close()


def plot_spatial_attention_map(attn_weights, raw_img_np, feat_h, feat_w,
                               sample_idx=0, save_path=None):
    attn         = attn_weights[sample_idx].mean(dim=0)
    spatial_attn = attn[1:, 1:].mean(dim=0).cpu().numpy()
    if len(spatial_attn) == feat_h * feat_w:
        spatial = spatial_attn.reshape(feat_h, feat_w)
    else:
        pad = np.zeros(feat_h * feat_w)
        pad[:len(spatial_attn)] = spatial_attn
        spatial = pad.reshape(feat_h, feat_w)
    spatial_up = np.array(
        Image.fromarray(
            (spatial / (spatial.max() + 1e-8) * 255).astype(np.uint8)
        ).resize((CFG.IMG_SIZE, CFG.IMG_SIZE), Image.BILINEAR)
    ) / 255.0
    fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    axes[0].imshow(raw_img_np);  axes[0].set_title("Original image");  axes[0].axis("off")
    im = axes[1].imshow(spatial, cmap="hot")
    axes[1].set_title("Patch attention (grid)"); axes[1].axis("off")
    plt.colorbar(im, ax=axes[1], fraction=0.046)
    axes[2].imshow(raw_img_np)
    axes[2].imshow(spatial_up, cmap="hot", alpha=0.5)
    axes[2].set_title("Clinical → Visual attention overlay"); axes[2].axis("off")
    plt.suptitle("Where do clinical features focus in the image?", fontweight="bold")
    plt.tight_layout()
    if save_path:
        plt.savefig(save_path, dpi=150, bbox_inches="tight")
    plt.show(); plt.close()


# ─── 19. Core Training Function ───────────────────────────────────────────────
def run_training(train_df, val_df, meta_cols, fold=None):
    tag = f"fold{fold}" if fold else "model"
    print(f"\n{'='*65}")
    print(f"  EfficientNetV2-S × TabTransformer — v2 Fixed")
    print(f"  {'Fold ' + str(fold) if fold else 'Single Split'}")
    print(f"  Train: {len(train_df):,}  |  Val: {len(val_df):,}")
    print(f"  Meta features: {len(meta_cols)}")
    print(f"{'='*65}")

    train_ds = ISICDataset(train_df, CFG.IMAGES_DIR, augment=True)
    val_ds   = ISICDataset(val_df,   CFG.IMAGES_DIR, augment=False)

    model   = EfficientFusionModel(meta_dim=len(meta_cols)).to(CFG.DEVICE)
    total_p = sum(p.numel() for p in model.parameters())
    train_p = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"\n  Total params    : {total_p:,}")
    print(f"  Trainable params: {train_p:,}")

    backbone_params = [p for n, p in model.named_parameters()
                       if "img_encoder.backbone" in n and p.requires_grad]
    head_params     = [p for n, p in model.named_parameters()
                       if "img_encoder.backbone" not in n and p.requires_grad]

    optimizer  = optim.AdamW([
        {"params": backbone_params, "lr": CFG.LR_BACKBONE},
        {"params": head_params,     "lr": CFG.LR_HEAD},
    ], weight_decay=CFG.WEIGHT_DECAY)

    scheduler  = WarmupCosineScheduler(
        optimizer, CFG.WARMUP_EPOCHS, CFG.EPOCHS, min_lr=1e-6
    )
    criterion  = MixLoss(CFG.FOCAL_ALPHA, CFG.FOCAL_GAMMA, CFG.LABEL_SMOOTH)
    scaler_amp = torch.amp.GradScaler("cuda", enabled=(CFG.DEVICE == "cuda"))

    ema_auc    = EMAMetric(alpha=CFG.EMA_ALPHA)
    best_ema   = 0.0
    patience_c = 0
    best_thr   = 0.5
    ckpt_path  = os.path.join(CFG.OUTPUT_DIR, f"best_efficient_v2_{tag}.pth")

    history = {
        "train_loss": [], "val_loss": [],
        "train_auc":  [], "val_auc": [], "val_auc_ema": [],
        "val_f1":     [], "threshold": []
    }

    for epoch in range(1, CFG.EPOCHS + 1):

        if epoch == CFG.UNFREEZE_EPOCH_1:
            model.unfreeze_backbone_blocks(2, CFG.FREEZE_BLOCKS)
            new_params = model.get_newly_unfrozen_params(2, CFG.FREEZE_BLOCKS)
            if new_params:
                new_lr = CFG.LR_BACKBONE * 0.5
                optimizer.add_param_group({"params": new_params, "lr": new_lr})
                scheduler.add_new_param_group(new_lr)

        if epoch == CFG.UNFREEZE_EPOCH_2:
            model.unfreeze_backbone_blocks(0, 2)
            new_params = model.get_newly_unfrozen_params(0, 2)
            if new_params:
                new_lr = CFG.LR_BACKBONE * 0.1
                optimizer.add_param_group({"params": new_params, "lr": new_lr})
                scheduler.add_new_param_group(new_lr)

        sampler = make_weighted_sampler(
            train_df[CFG.TARGET_COL].values, epoch=epoch
        )
        train_loader = DataLoader(
            train_ds, batch_size=CFG.BATCH_SIZE, sampler=sampler,
            num_workers=CFG.NUM_WORKERS, pin_memory=True
        )
        val_loader = DataLoader(
            val_ds, batch_size=CFG.BATCH_SIZE, shuffle=False,
            num_workers=CFG.NUM_WORKERS, pin_memory=True
        )

        lrs = scheduler.get_lr()
        print(f"\n  Epoch {epoch:02d}/{CFG.EPOCHS}  "
              f"| LR backbone={lrs[0]:.1e}  head={lrs[1]:.1e}"
              + (f"  unfrozen={lrs[2]:.1e}" if len(lrs) > 2 else ""))

        tr_loss, tr_auc = train_one_epoch(
            model, train_loader, optimizer, criterion, scaler_amp, CFG.DEVICE
        )
        vl_loss, vl_auc, _, vl_labels, _, vl_probs = evaluate(
            model, val_loader, criterion, CFG.DEVICE, threshold=0.5
        )
        opt_thr, youden_j = find_optimal_threshold(vl_labels, vl_probs)
        vl_preds_opt      = (vl_probs >= opt_thr).astype(int)
        vl_f1_opt         = f1_score(vl_labels, vl_preds_opt, average="macro")

        smooth_auc = ema_auc.update(vl_auc)
        scheduler.step(epoch)

        history["train_loss"].append(tr_loss)
        history["val_loss"].append(vl_loss)
        history["train_auc"].append(tr_auc)
        history["val_auc"].append(vl_auc)
        history["val_auc_ema"].append(smooth_auc)
        history["val_f1"].append(vl_f1_opt)
        history["threshold"].append(opt_thr)

        print(f"  Train → Loss: {tr_loss:.4f}  AUC: {tr_auc:.4f}")
        print(f"  Val   → Loss: {vl_loss:.4f}  AUC: {vl_auc:.4f}  "
              f"EMA: {smooth_auc:.4f}  F1: {vl_f1_opt:.4f}  "
              f"thresh: {opt_thr:.3f}  J: {youden_j:.3f}")

        if smooth_auc > best_ema:
            best_ema   = smooth_auc
            best_thr   = opt_thr
            patience_c = 0
            torch.save({
                "epoch":            epoch,
                "model_state_dict": model.state_dict(),
                "val_auc_raw":      vl_auc,
                "val_auc_ema":      smooth_auc,
                "val_f1":           vl_f1_opt,
                "threshold":        opt_thr,
                "meta_cols":        meta_cols,
                "meta_dim":         len(meta_cols),
                "feat_h":           model.img_encoder.feat_h,
                "feat_w":           model.img_encoder.feat_w,
            }, ckpt_path)
            print(f"  ✅ Saved  EMA-AUC: {best_ema:.4f}  threshold: {opt_thr:.3f}")
        else:
            patience_c += 1
            print(f"  ⏳ No improvement ({patience_c}/{CFG.PATIENCE})")
            if patience_c >= CFG.PATIENCE:
                print("  🛑 Early stopping.")
                break

        if CFG.DEVICE == "cuda":
            torch.cuda.empty_cache(); gc.collect()

    # ── Final evaluation ──────────────────────────────────────────────────────
    print(f"\n{'─'*65}")
    print(f"  FINAL RESULTS  (EMA-AUC: {best_ema:.4f}  threshold: {best_thr:.3f})")
    print(f"{'─'*65}")

    ckpt = torch.load(ckpt_path, map_location=CFG.DEVICE, weights_only=False)
    model.load_state_dict(ckpt["model_state_dict"])
    saved_thr = ckpt["threshold"]
    feat_h    = ckpt["feat_h"]
    feat_w    = ckpt["feat_w"]

    _, final_auc, _, final_labels, _, final_probs = evaluate(
        model, val_loader, criterion, CFG.DEVICE, threshold=0.5
    )
    final_preds = (final_probs >= saved_thr).astype(int)
    final_f1    = f1_score(final_labels, final_preds, average="macro")
    print(f"\n  Standard AUC : {final_auc:.4f}  F1: {final_f1:.4f}")

    tta_auc, tta_f1, tta_labels, tta_preds, tta_probs = evaluate_with_tta(
        model, val_ds, criterion, CFG.DEVICE, threshold=saved_thr
    )
    print(f"  TTA AUC      : {tta_auc:.4f}  F1: {tta_f1:.4f}  "
          f"(+{(tta_auc - final_auc)*100:.2f}% from TTA)")

    print(f"\n  Classification Report (TTA, threshold={saved_thr:.3f}):")
    print(classification_report(
        tta_labels, tta_preds,
        target_names=["Non-Melanoma", "Melanoma"], digits=4
    ))

    # ── Built-in attention plots ───────────────────────────────────────────────
    print("\n  Generating built-in attention visualizations…")
    model.eval()
    xai_loader = DataLoader(val_ds, batch_size=CFG.BATCH_SIZE,
                            shuffle=False, num_workers=0)
    sample_img, sample_meta, _ = next(iter(xai_loader))
    with torch.no_grad():
        with torch.amp.autocast("cuda", enabled=(CFG.DEVICE == "cuda")):
            _ = model(sample_img.to(CFG.DEVICE), sample_meta.to(CFG.DEVICE))
    attn = model.get_attention_weights()
    plot_attention_heatmap(
        attn, meta_cols, sample_idx=0,
        save_path=os.path.join(
            CFG.OUTPUT_DIR,
            f"xai_feature_attention_v2{'_fold'+str(fold) if fold else ''}.png"
        )
    )
    plot_spatial_attention_map(
        attn,
        raw_img_np=sample_img[0].permute(1, 2, 0).numpy() *
                   np.array(CFG.STD) + np.array(CFG.MEAN),
        feat_h=feat_h, feat_w=feat_w, sample_idx=0,
        save_path=os.path.join(
            CFG.OUTPUT_DIR,
            f"xai_spatial_attention_v2{'_fold'+str(fold) if fold else ''}.png"
        )
    )

    plot_training_curves(history, fold=fold)
    plot_confusion_matrix(tta_labels, tta_preds, saved_thr, fold=fold)
    plot_roc_curve(tta_labels, tta_probs, tta_auc, saved_thr, fold=fold)

    # ── Per-sample XAI (no SHAP) ──────────────────────────────────────────────
    run_all_xai(
        model          = model,
        val_df         = val_df,
        meta_cols_used = meta_cols,
        feat_h         = feat_h,
        feat_w         = feat_w,
        fold           = fold,
    )

    # ── Save val_df for the SHAP cell ─────────────────────────────────────────
    val_df_path = os.path.join(CFG.OUTPUT_DIR, f"val_df{'_fold'+str(fold) if fold else ''}.csv")
    val_df.to_csv(val_df_path, index=False)
    print(f"\n  📄 val_df saved → {val_df_path}")
    print(f"  ▶  Run the SHAP cell next for global feature importance.")

    return model, tta_auc, tta_f1, tta_probs, tta_labels


# ─── 20. Main ─────────────────────────────────────────────────────────────────
def main():
    print("\n" + "═" * 65)
    print("  ISIC-DICM-17K  |  EfficientNetV2-S + TabTransformer")
    print("  Cross-Attention Fusion  —  v2 FIXED  +  XAI (no SHAP)")
    print("═" * 65)

    df = pd.read_csv(CFG.CSV_PATH)

    def extract_id(filename):
        match = re.search(r'(\d{7})', str(filename))
        return f"ISIC_{match.group(1)}.jpg" if match else filename

    print(f"Normalizing {len(df)} image names…")
    df[CFG.IMG_COL] = df[CFG.IMG_COL].apply(extract_id)

    meta_cols = [c for c in df.columns if c not in CFG.DROP_COLS]
    validate_features(df, meta_cols)

    if CFG.USE_KFOLD:
        print(f"\nRunning {CFG.N_FOLDS}-Fold Stratified CV")
        skf        = StratifiedKFold(n_splits=CFG.N_FOLDS, shuffle=True,
                                     random_state=CFG.SEED)
        fold_aucs, fold_f1s = [], []
        oof_probs  = np.zeros(len(df))
        oof_labels = np.zeros(len(df))
        for fold, (tr_idx, vl_idx) in enumerate(
                skf.split(df, df[CFG.TARGET_COL]), 1):
            model, auc, f1, probs, labels = run_training(
                df.iloc[tr_idx], df.iloc[vl_idx], meta_cols, fold=fold
            )
            fold_aucs.append(auc)
            fold_f1s.append(f1)
            oof_probs[vl_idx]  = probs
            oof_labels[vl_idx] = labels
        oof_auc = roc_auc_score(oof_labels, oof_probs)
        print(f"\n{'═'*65}")
        print(f"  K-FOLD SUMMARY")
        print(f"  Per-fold AUC  : {[f'{a:.4f}' for a in fold_aucs]}")
        print(f"  Mean AUC      : {np.mean(fold_aucs):.4f} ± {np.std(fold_aucs):.4f}")
        print(f"  OOF AUC       : {oof_auc:.4f}")
        print(f"  Mean F1 macro : {np.mean(fold_f1s):.4f}")
        print(f"{'═'*65}")
        oof_df = pd.DataFrame({"label": oof_labels, "prob_melanoma": oof_probs})
        oof_df.to_csv(
            os.path.join(CFG.OUTPUT_DIR, "oof_predictions_efficient_v2.csv"),
            index=False
        )
    else:
        train_df, val_df = train_test_split(
            df, test_size=0.2,
            stratify=df[CFG.TARGET_COL],
            random_state=CFG.SEED
        )
        run_training(train_df, val_df, meta_cols)

    print(f"\nAll outputs saved to: {CFG.OUTPUT_DIR}")


if __name__ == "__main__":
    main()
# Out:
# Device : cuda
# GPU    : Tesla T4
#
# ═════════════════════════════════════════════════════════════════
#   ISIC-DICM-17K  |  EfficientNetV2-S + TabTransformer
#   Cross-Attention Fusion  —  v2 FIXED  +  XAI (no SHAP)
# ═════════════════════════════════════════════════════════════════
# Normalizing 17059 image names…
#
# ── Feature validation ──
#   Sparse features (>99% zeros) — keeping as missing-data signal:
#     diagnosis_confirm_type_confocal microscopy with consensus dermoscopy (99.5% zeros)
#   Passed — 23 clean features ready for training.
#
#
# =================================================================
#   EfficientNetV2-S × TabTransformer — v2 Fixed
#   Single Split
#   Train: 13,647  |  Val: 3,412
#   Meta features: 23
# =================================================================
#   EfficientNetV2-S feature map: 1280×12×12 → 144 spatial tokens
#
#   Total params    : 21,269,586
#   Trainable params: 19,448,010
#
#   Epoch 01/40  | LR backbone=2.0e-05  head=2.0e-04
#   Train → Loss: 0.0363  AUC: 0.8111
#   Val   → Loss: 0.0282  AUC: 0.9155  EMA: 0.9155  F1: 0.8209  thresh: 0.448  J: 0.644
#   ✅ Saved  EMA-AUC: 0.9155  threshold: 0.448
#
#   Epoch 02/40  | LR backbone=6.7e-06  head=6.7e-05
#   Train → Loss: 0.0326  AUC: 0.8841
#   Val   → Loss: 0.0263  AUC: 0.9241  EMA: 0.9180  F1: 0.8326  thresh: 0.468  J: 0.668
#   ✅ Saved  EMA-AUC: 0.9180  threshold: 0.468
#
#   Epoch 03/40  | LR backbone=1.3e-05  head=1.3e-04
#   Train → Loss: 0.0327  AUC: 0.8833
#   Val   → Loss: 0.0265  AUC: 0.9226  EMA: 0.9194  F1: 0.8356  thresh: 0.496  J: 0.671
#   ✅ Saved  EMA-AUC: 0.9194  threshold: 0.496
#
#   Epoch 04/40  | LR backbone=2.0e-05  head=2.0e-04
#   Train → Loss: 0.0320  AUC: 0.8885
#   Val   → Loss: 0.0262  AUC: 0.9240  EMA: 0.9208  F1: 0.8410  thresh: 0.495  J: 0.682
#   ✅ Saved  EMA-AUC: 0.9208  threshold: 0.495
#
#   Epoch 05/40  | LR backbone=2.0e-05  head=2.0e-04
#   Train → Loss: 0.0317  AUC: 0.8939
#   Val   → Loss: 0.0259  AUC: 0.9290  EMA: 0.9232  F1: 0.8448  thresh: 0.471  J: 0.691
#   ✅ Saved  EMA-AUC: 0.9232  threshold: 0.471
#
#   Epoch 06/40  | LR backbone=2.0e-05  head=2.0e-04
#   Train → Loss: 0.0313  AUC: 0.8959
#   Val   → Loss: 0.0263  AUC: 0.9256  EMA: 0.9240  F1: 0.8357  thresh: 0.450  J: 0.672
#   ✅ Saved  EMA-AUC: 0.9240  threshold: 0.450
#
#   Epoch 07/40  | LR backbone=2.0e-05  head=2.0e-04
#   Train → Loss: 0.0308  AUC: 0.9056
#   Val   → Loss: 0.0252  AUC: 0.9297  EMA: 0.9257  F1: 0.8459  thresh: 0.490  J: 0.692
#   ✅ Saved  EMA-AUC: 0.9257  threshold: 0.490
#
#   Epoch 08/40  | LR backbone=2.0e-05  head=2.0e-04
#   Train → Loss: 0.0307  AUC: 0.9023
#   Val   → Loss: 0.0243  AUC: 0.9331  EMA: 0.9279  F1: 0.8514  thresh: 0.485  J: 0.703
#   ✅ Saved  EMA-AUC: 0.9279  threshold: 0.485
#
#   Epoch 09/40  | LR backbone=1.9e-05  head=1.9e-04
#   Train → Loss: 0.0302  AUC: 0.9098
#   Val   → Loss: 0.0250  AUC: 0.9298  EMA: 0.9285  F1: 0.8451  thresh: 0.465  J: 0.691
#   ✅ Saved  EMA-AUC: 0.9285  threshold: 0.465
#   🔓 Unfroze blocks 2–3 | Backbone trainable params: 19,862,776
#
#   Epoch 10/40  | LR backbone=1.9e-05  head=1.9e-04  unfrozen=1.0e-05
#   Train → Loss: 0.0305  AUC: 0.9059
#   Val   → Loss: 0.0249  AUC: 0.9285  EMA: 0.9285  F1: 0.8439  thresh: 0.474  J: 0.689
#   ✅ Saved  EMA-AUC: 0.9285  threshold: 0.474
#
#   Epoch 11/40  | LR backbone=1.9e-05  head=1.9e-04  unfrozen=9.4e-06
#   Train → Loss: 0.0297  AUC: 0.9093
#   Val   → Loss: 0.0240  AUC: 0.9385  EMA: 0.9315  F1: 0.8557  thresh: 0.489  J: 0.712
#   ✅ Saved  EMA-AUC: 0.9315  threshold: 0.489
#
#   Epoch 12/40  | LR backbone=1.8e-05  head=1.8e-04  unfrozen=9.1e-06
#   Train → Loss: 0.0292  AUC: 0.9094
#   Val   → Loss: 0.0256  AUC: 0.9315  EMA: 0.9315  F1: 0.8542  thresh: 0.449  J: 0.709
#   ⏳ No improvement (1/10)
#
#   Epoch 13/40  | LR backbone=1.8e-05  head=1.8e-04  unfrozen=8.9e-06
#   Train → Loss: 0.0291  AUC: 0.9124
#   Val   → Loss: 0.0245  AUC: 0.9337  EMA: 0.9321  F1: 0.8575  thresh: 0.438  J: 0.716
#   ✅ Saved  EMA-AUC: 0.9321  threshold: 0.438
#
#   Epoch 14/40  | LR backbone=1.7e-05  head=1.7e-04  unfrozen=8.6e-06
#   Train → Loss: 0.0294  AUC: 0.9117
#   Val   → Loss: 0.0241  AUC: 0.9374  EMA: 0.9337  F1: 0.8570  thresh: 0.448  J: 0.715
#   ✅ Saved  EMA-AUC: 0.9337  threshold: 0.448
#
#   Epoch 15/40  | LR backbone=1.7e-05  head=1.7e-04  unfrozen=8.3e-06
#   Train → Loss: 0.0286  AUC: 0.9172
#   Val   → Loss: 0.0244  AUC: 0.9358  EMA: 0.9343  F1: 0.8557  thresh: 0.467  J: 0.712
#   ✅ Saved  EMA-AUC: 0.9343  threshold: 0.467
#
#   Epoch 16/40  | LR backbone=1.6e-05  head=1.6e-04  unfrozen=8.0e-06
#   Train → Loss: 0.0279  AUC: 0.9220
#   Val   → Loss: 0.0248  AUC: 0.9379  EMA: 0.9354  F1: 0.8585  thresh: 0.460  J: 0.717
#   ✅ Saved  EMA-AUC: 0.9354  threshold: 0.460
#
#   Epoch 17/40  | LR backbone=1.5e-05  head=1.5e-04  unfrozen=7.6e-06
#   Train → Loss: 0.0280  AUC: 0.9222
#   Val   → Loss: 0.0239  AUC: 0.9401  EMA: 0.9368  F1: 0.8627  thresh: 0.456  J: 0.726
#   ✅ Saved  EMA-AUC: 0.9368  threshold: 0.456
#
#   Epoch 18/40  | LR backbone=1.5e-05  head=1.5e-04  unfrozen=7.3e-06
#   Train → Loss: 0.0286  AUC: 0.9133
#   Val   → Loss: 0.0250  AUC: 0.9330  EMA: 0.9357  F1: 0.8528  thresh: 0.451  J: 0.706
#   ⏳ No improvement (1/10)
#
#   Epoch 19/40  | LR backbone=1.4e-05  head=1.4e-04  unfrozen=6.9e-06
#   Train → Loss: 0.0277  AUC: 0.9226
#   Val   → Loss: 0.0252  AUC: 0.9381  EMA: 0.9364  F1: 0.8632  thresh: 0.422  J: 0.727
#   ⏳ No improvement (2/10)
#   🔓 Unfroze blocks 0–1 | Backbone trainable params: 20,176,792
#
#   Epoch 20/40  | LR backbone=1.3e-05  head=1.3e-04  unfrozen=6.5e-06
#   Train → Loss: 0.0271  AUC: 0.9287
#   Val   → Loss: 0.0245  AUC: 0.9375  EMA: 0.9367  F1: 0.8592  thresh: 0.431  J: 0.719
#   ⏳ No improvement (3/10)
#
#   Epoch 21/40  | LR backbone=1.2e-05  head=1.2e-04  unfrozen=6.1e-06
#   Train → Loss: 0.0270  AUC: 0.9229
#   Val   → Loss: 0.0239  AUC: 0.9417  EMA: 0.9382  F1: 0.8650  thresh: 0.399  J: 0.731
#   ✅ Saved  EMA-AUC: 0.9382  threshold: 0.399
#
#   Epoch 22/40  | LR backbone=1.1e-05  head=1.1e-04  unfrozen=5.6e-06
#   Train → Loss: 0.0271  AUC: 0.9240
#   Val   → Loss: 0.0238  AUC: 0.9404  EMA: 0.9398  F1: 0.8630  thresh: 0.462  J: 0.726
#   ✅ Saved  EMA-AUC: 0.9398  threshold: 0.462
#
#   Epoch 24/40  | LR backbone=9.6e-06  head=9.6e-05  unfrozen=4.8e-06
#   Train → Loss: 0.0267  AUC: 0.9236
#   Val   → Loss: 0.0253  AUC: 0.9372  EMA: 0.9390  F1: 0.8610  thresh: 0.428  J: 0.722
#   ⏳ No improvement (2/10)
#
#   Epoch 26/40  | LR backbone=7.9e-06  head=7.9e-05  unfrozen=3.9e-06
#   Train → Loss: 0.0259  AUC: 0.9332
#   Val   → Loss: 0.0233  AUC: 0.9416  EMA: 0.9397  F1: 0.8645  thresh: 0.452  J: 0.730
#   ⏳ No improvement (3/10)
#
#   Epoch 27/40  | LR backbone=7.1e-06  head=7.1e-05  unfrozen=3.5e-06
#   Train → Loss: 0.0266  AUC: 0.9291
#   Val   → Loss: 0.0239  AUC: 0.9398  EMA: 0.9398  F1: 0.8694  thresh: 0.453  J: 0.739
#   ⏳ No improvement (4/10)
#
#   Epoch 28/40  | LR backbone=6.3e-06  head=6.3e-05  unfrozen=3.1e-06
#   Train → Loss: 0.0258  AUC: 0.9384
#   Val   → Loss: 0.0239  AUC: 0.9409  EMA: 0.9401  F1: 0.8650  thresh: 0.434  J: 0.730
#   ✅ Saved  EMA-AUC: 0.9401  threshold: 0.434
#
#   Epoch 29/40  | LR backbone=5.5e-06  head=5.5e-05  unfrozen=2.7e-06
#   Train → Loss: 0.0260  AUC: 0.9335
#   Val   → Loss: 0.0237  AUC: 0.9419  EMA: 0.9406  F1: 0.8648  thresh: 0.455  J: 0.730
#   ✅ Saved  EMA-AUC: 0.9406  threshold: 0.455
#
#   Epoch 30/40  | LR backbone=4.8e-06  head=4.8e-05  unfrozen=2.4e-06
#   Train → Loss: 0.0258  AUC: 0.9312
#   Val   → Loss: 0.0242  AUC: 0.9406  EMA: 0.9406  F1: 0.8648  thresh: 0.400  J: 0.730
#   ⏳ No improvement (1/10)
#
#   Epoch 31/40  | LR backbone=4.1e-06  head=4.1e-05  unfrozen=2.0e-06
#   Train → Loss: 0.0259  AUC: 0.9344
#   Val   → Loss: 0.0235  AUC: 0.9439  EMA: 0.9416  F1: 0.8697  thresh: 0.437  J: 0.740
#   ✅ Saved  EMA-AUC: 0.9416  threshold: 0.437
#
#   Epoch 32/40  | LR backbone=3.4e-06  head=3.4e-05  unfrozen=1.7e-06
#   Train → Loss: 0.0262  AUC: 0.9282
#   Val   → Loss: 0.0240  AUC: 0.9405  EMA: 0.9413  F1: 0.8641  thresh: 0.432  J: 0.729
#   ⏳ No improvement (1/10)
#
#   Epoch 33/40  | LR backbone=2.8e-06  head=2.8e-05  unfrozen=1.4e-06
#   Train → Loss: 0.0254  AUC: 0.9345
#   Val   → Loss: 0.0239  AUC: 0.9408  EMA: 0.9411  F1: 0.8659  thresh: 0.442  J: 0.732
#   ⏳ No improvement (2/10)
#
#   Epoch 34/40  | LR backbone=2.2e-06  head=2.2e-05  unfrozen=1.1e-06
#   Train → Loss: 0.0253  AUC: 0.9355
#   Val   → Loss: 0.0234  AUC: 0.9443  EMA: 0.9421  F1: 0.8682  thresh: 0.444  J: 0.737
#   ✅ Saved  EMA-AUC: 0.9421  threshold: 0.444
#
#   Epoch 35/40  | LR backbone=1.7e-06  head=1.7e-05  unfrozen=8.6e-07
#   Train → Loss: 0.0251  AUC: 0.9382
#   Val   → Loss: 0.0238  AUC: 0.9414  EMA: 0.9419  F1: 0.8678  thresh: 0.484  J: 0.736
#   ⏳ No improvement (1/10)
#
#   Epoch 36/40  | LR backbone=1.3e-06  head=1.3e-05  unfrozen=6.3e-07
#   Train → Loss: 0.0256  AUC: 0.9379
#   Val   → Loss: 0.0239  AUC: 0.9406  EMA: 0.9415  F1: 0.8646  thresh: 0.484  J: 0.729
#   ⏳ No improvement (2/10)
#
#   Epoch 37/40  | LR backbone=8.9e-07  head=8.9e-06  unfrozen=4.4e-07
#   Train → Loss: 0.0255  AUC: 0.9362
#   Val   → Loss: 0.0240  AUC: 0.9416  EMA: 0.9415  F1: 0.8690  thresh: 0.475  J: 0.738
#   ⏳ No improvement (3/10)
#
#   Epoch 38/40  | LR backbone=5.7e-07  head=5.7e-06  unfrozen=2.9e-07
#   Train → Loss: 0.0250  AUC: 0.9414
#   Val   → Loss: 0.0236  AUC: 0.9434  EMA: 0.9421  F1: 0.8699  thresh: 0.473  J: 0.740
#   ⏳ No improvement (4/10)
#
#   Epoch 39/40  | LR backbone=3.2e-07  head=3.2e-06  unfrozen=1.6e-07
#   Train → Loss: 0.0248  AUC: 0.9409
#   Val   → Loss: 0.0241  AUC: 0.9411  EMA: 0.9418  F1: 0.8656  thresh: 0.431  J: 0.732
#   ⏳ No improvement (5/10)
#
#   Epoch 40/40  | LR backbone=1.4e-07  head=1.4e-06  unfrozen=7.2e-08
#   Train → Loss: 0.0257  AUC: 0.9356
#   Val   → Loss: 0.0233  AUC: 0.9449  EMA: 0.9427  F1: 0.8725  thresh: 0.479  J: 0.745
#   ✅ Saved  EMA-AUC: 0.9427  threshold: 0.479
#
# ─────────────────────────────────────────────────────────────────
#   FINAL RESULTS  (EMA-AUC: 0.9427  threshold: 0.479)
# ─────────────────────────────────────────────────────────────────
#   Standard AUC : 0.9449  F1: 0.8725
#   Running TTA inference...
#   TTA AUC: 0.9489  F1: 0.8739
#   TTA AUC      : 0.9489  F1: 0.8739  (+0.40% from TTA)
#
#   Classification Report (TTA, threshold=0.479):
#               precision    recall  f1-score   support
#
# Non-Melanoma     0.8857    0.8587    0.8720      1706
#     Melanoma     0.8629    0.8892    0.8759      1706
#
#     accuracy                         0.8740      3412
#    macro avg     0.8743    0.8740    0.8739      3412
# weighted avg     0.8743    0.8740    0.8739      3412
#
#
#   Generating built-in attention visualizations…
# Saved: /kaggle/working/efficient_v2_outputs/training_curves_efficient_v2.png
# ═════════════════════════════════════════════════════════════════
#   XAI Suite  (Single run)
#   Methods: Grad-CAM, Grad-CAM++, Integrated Gradients (multimodal),
#            Attention Rollout, Cross-Attention
#   NOTE: SHAP runs in the NEXT cell — run it separately.
#   Samples : 5 individual
# ═════════════════════════════════════════════════════════════════
#
#
#   ── Sample 1/5  (Melanoma) ──
#   ✔ /kaggle/working/efficient_v2_outputs/xai_gradcam_s1.png
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# /tmp/ipykernel_55/2468579733.py in <cell line: 0>()
#    1420
#    1421 if __name__ == "__main__":
# -> 1422     main()
#
# /tmp/ipykernel_55/2468579733.py in main()
#    1414             random_state=CFG.SEED
#    1415         )
# -> 1416         run_training(train_df, val_df, meta_cols)
#    1417
#    1418     print(f"\nAll outputs saved to: {CFG.OUTPUT_DIR}")
#
# /tmp/ipykernel_55/2468579733.py in run_training(train_df, val_df, meta_cols, fold)
#    1342
#    1343     # ── Per-sample XAI (no SHAP) ──────────────────────────────────────────────
# -> 1344     run_all_xai(
#    1345         model          = model,
#    1346         val_df         = val_df,
#
# /tmp/ipykernel_55/2468579733.py in run_all_xai(model, val_df, meta_cols_used, feat_h, feat_w, fold)
#    1077                        save_tag=tag)
#    1078
# -> 1079         xai_integrated_gradients(model, img_t, meta_t, rgb, meta_cols_used,
#    1080                                   save_tag=tag)
#    1081
#
# /tmp/ipykernel_55/2468579733.py in xai_integrated_gradients(model, img_t, meta_t, rgb, meta_cols_used, save_tag, class_idx, n_steps)
#     878
#     879     model.zero_grad()
# --> 880     attr, delta = ig_eng.attribute(
#     881         inputs    = (img_t, meta_t),
#     882         baselines = (torch.zeros_like(img_t), torch.zeros_like(meta_t)),
#
# /usr/local/lib/python3.12/dist-packages/captum/log/dummy_log.py in wrapper(*args, **kwargs)
#      52             # pyre-fixme[2]: Parameter must be annotated.
#      53             def wrapper(*args, **kwargs):
# ---> 54                 return func(*args, **kwargs)
#      55
#      56             return wrapper
#
# /usr/local/lib/python3.12/dist-packages/captum/attr/_core/integrated_gradients.py in attribute(self, inputs, baselines, target, additional_forward_args, n_steps, method, internal_batch_size, return_convergence_delta)
#     283             )
#     284         else:
# --> 285             attributions = self._attribute(
#     286                 inputs=formatted_inputs,
#     287                 baselines=formatted_baselines,
#
# /usr/local/lib/python3.12/dist-packages/captum/attr/_core/integrated_gradients.py in _attribute(self, inputs, baselines, target, additional_forward_args, n_steps, method, step_sizes_and_alphas)
#     364
#     365         # grads: dim -> (bsz * #steps x inputs[0].shape[1:], ...)
# --> 366         grads = self.gradient_func(
#     367             forward_fn=self.forward_func,
#     368             inputs=scaled_features_tpl,
#
# /usr/local/lib/python3.12/dist-packages/captum/_utils/gradient.py in compute_gradients(forward_fn, inputs, target_ind, additional_forward_args)
#     126     with torch.autograd.set_grad_enabled(True):
#     127         # runs forward pass
# --> 128         outputs = _run_forward(forward_fn, inputs, target_ind, additional_forward_args)
#     129         # _run_forward may return future of Tensor,
#     130         # but we don't support it here now
#
# /usr/local/lib/python3.12/dist-packages/captum/_utils/common.py in _run_forward(forward_func, inputs, target, additional_forward_args)
#     597     additional_forward_args = _format_additional_forward_args(additional_forward_args)
#     598
# --> 599     output = forward_func(
#     600         *(
#     601             # pyre-fixme[60]: Concatenation not yet support for multiple variadic
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /tmp/ipykernel_55/2468579733.py in forward(self, image, meta)
#     497
#     498     def forward(self, image, meta):
# --> 499         img_tokens  = self.img_encoder(image)
#     500         meta_tokens = self.meta_encoder(meta)
#     501         for ca in self.ca_layers:
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /tmp/ipykernel_55/2468579733.py in forward(self, x)
#     384
#     385     def forward(self, x):
# --> 386         feats  = self.backbone(x)
#     387         tokens = self.proj(feats)
#     388         B, D, H, W = tokens.shape
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/timm/models/efficientnet.py in forward(self, x)
#     346     def forward(self, x: torch.Tensor) -> torch.Tensor:
#     347         """Forward pass."""
# --> 348         x = self.forward_features(x)
#     349         x = self.forward_head(x)
#     350         return x
#
# /usr/local/lib/python3.12/dist-packages/timm/models/efficientnet.py in forward_features(self, x)
#     324             x = checkpoint_seq(self.blocks, x, flatten=True)
#     325         else:
# --> 326             x = self.blocks(x)
#     327         x = self.conv_head(x)
#     328         x = self.bn2(x)
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     251         """
#     252         for module in self:
# --> 253             input = module(input)
#     254         return input
#     255
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     251         """
#     252         for module in self:
# --> 253             input = module(input)
#     254         return input
#     255
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/timm/models/_efficientnet_blocks.py in forward(self, x)
#     332         x = self.bn2(x)
#     333         x = self.aa(x)
# --> 334         x = self.se(x)
#     335         x = self.conv_pwl(x)
#     336         x = self.bn3(x)
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/timm/models/_efficientnet_blocks.py in forward(self, x)
#      81         x_se = self.act1(x_se)
#      82         x_se = self.conv_expand(x_se)
# ---> 83         return x * self.gate(x_se)
#      84
#      85
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 106.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 99.81 MiB is free. Including non-PyTorch memory, this process has 14.46 GiB memory in use. Of the allocated memory 13.89 GiB is allocated by PyTorch, and 438.67 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
"""
╔══════════════════════════════════════════════════════════════════════════════╗
║              SHAP — Global Clinical Feature Importance                       ║
║         Run this cell AFTER the training cell has finished.                  ║
╚══════════════════════════════════════════════════════════════════════════════╝

Prerequisites (already satisfied if Cell 1 ran):
  • best_efficient_v2_model.pth  saved in CFG.OUTPUT_DIR
  • val_df.csv                   saved in CFG.OUTPUT_DIR
  • EfficientFusionModel class   defined in Cell 1 (same session)

Outputs:
  • xai_shap_bar.png             — mean |SHAP| bar chart (top 25 features)
  • xai_shap_beeswarm.png        — SHAP beeswarm summary plot
  • xai_shap_importance.csv      — full per-feature SHAP scores
"""

import os, gc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from PIL import Image
from torchvision import transforms
import shap
import warnings
warnings.filterwarnings("ignore")

# ─── SHAP Configuration ───────────────────────────────────────────────────────
# Paths — must match what Cell 1 used
OUTPUT_DIR = "/kaggle/working/efficient_v2_outputs/"
IMAGES_DIR = "/kaggle/input/datasets/ahmedmohsen2005/xai-preprocessed-skin-lesion-17k-dataset/final_processed_images"
IMG_COL    = "image"
TARGET_COL = "class"
DEVICE     = "cuda" if torch.cuda.is_available() else "cpu"

# SHAP sampling knobs — increase for more accurate results (slower)
SHAP_BACKGROUND = 60    # rows used to build the background distribution
SHAP_NSAMPLES   = 50    # KernelExplainer iterations per explained row
SHAP_EXPLAIN    = 20    # number of val rows to explain
SHAP_TOP_K      = 25    # features shown in plots

# Image normalisation (must match Cell 1)
IMG_SIZE = 384
MEAN     = [0.485, 0.456, 0.406]
STD      = [0.229, 0.224, 0.225]

_XAI_TF = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(MEAN, STD),
])

# ─── Helper ───────────────────────────────────────────────────────────────────
def _save_fig(fig, name):
    path = os.path.join(OUTPUT_DIR, name)
    fig.savefig(path, dpi=150, bbox_inches="tight")
    plt.show()
    plt.close(fig)
    print(f"  ✔ saved → {path}")


# ─── 1. Load checkpoint ───────────────────────────────────────────────────────
# Auto-detect fold or single-run checkpoint
import glob
ckpt_candidates = sorted(glob.glob(os.path.join(OUTPUT_DIR, "best_efficient_v2_*.pth")))
if not ckpt_candidates:
    raise FileNotFoundError(f"No checkpoint found in {OUTPUT_DIR}")
CKPT_PATH = ckpt_candidates[0]          # use first found; change index for specific fold
print(f"Loading checkpoint: {CKPT_PATH}")

ckpt      = torch.load(CKPT_PATH, map_location=DEVICE, weights_only=False)
meta_cols = list(ckpt["meta_cols"])     # feature names saved during training
meta_dim  = ckpt["meta_dim"]
threshold = ckpt.get("threshold", 0.5)
print(f"  meta_dim  : {meta_dim}")
print(f"  threshold : {threshold:.3f}")
print(f"  features  : {meta_cols[:5]} … ({len(meta_cols)} total)")

# ─── 2. Rebuild model and load weights ───────────────────────────────────────
# EfficientFusionModel must already be defined (Cell 1 ran in same session).
# If running in a fresh kernel, paste the full model definition here.
model = EfficientFusionModel(meta_dim=meta_dim).to(DEVICE)
model.load_state_dict(ckpt["model_state_dict"])
model.eval()
print("  Model loaded ✔")

# ─── 3. Load validation DataFrame ─────────────────────────────────────────────
# Cell 1 saves val_df.csv; detect fold version automatically
val_df_candidates = sorted(glob.glob(os.path.join(OUTPUT_DIR, "val_df*.csv")))
if not val_df_candidates:
    raise FileNotFoundError(
        f"val_df.csv not found in {OUTPUT_DIR}. "
        "Make sure Cell 1 finished successfully."
    )
VAL_DF_PATH = val_df_candidates[0]
val_df = pd.read_csv(VAL_DF_PATH)
print(f"val_df loaded: {len(val_df)} rows  →  {VAL_DF_PATH}")

# ─── 4. Find a representative image for the fixed-image wrapper ───────────────
rep_img = None
import re
for _, row in val_df.sample(min(50, len(val_df)), random_state=42).iterrows():
    # Standardize the name inside the loop
    raw_name = str(row[IMG_COL])
    match = re.search(r'(\d{7})', raw_name)
    clean_name = f"ISIC_{match.group(1)}.jpg" if match else raw_name
    
    p = os.path.join(IMAGES_DIR, clean_name)
    if os.path.exists(p):
        rep_img = _XAI_TF(Image.open(p).convert("RGB")).unsqueeze(0).to(DEVICE)
        print(f"  Representative image found: {clean_name}")
        break

if rep_img is None:
    raise FileNotFoundError(
        "Could not find any valid image in val_df for SHAP background. "
        "Check IMAGES_DIR path."
    )

# ─── 5. Build background distribution ────────────────────────────────────────
print(f"\nBuilding background ({SHAP_BACKGROUND} rows)…")
bg_rows = val_df.sample(min(SHAP_BACKGROUND, len(val_df)), random_state=42)
bg_meta = bg_rows[meta_cols].values.astype(np.float32)

# ─── 6. Define the prediction function (image fixed, metadata varies) ─────────
@torch.no_grad()
def _predict_meta(meta_np):
    """
    Returns P(Melanoma) for a batch of metadata arrays.
    The dermoscopy image is held fixed at rep_img so SHAP can isolate
    the marginal contribution of each clinical feature.
    """
    x   = torch.tensor(meta_np, dtype=torch.float32).to(DEVICE)
    img = rep_img.expand(x.shape[0], -1, -1, -1)
    return torch.softmax(model(img, x), dim=1)[:, 1].cpu().numpy()

# ─── 7. Build KernelExplainer and compute SHAP values ────────────────────────
print("Building KernelExplainer…")
explainer = shap.KernelExplainer(_predict_meta, bg_meta)

exp_rows = val_df.sample(min(SHAP_EXPLAIN, len(val_df)), random_state=0)
exp_meta = exp_rows[meta_cols].values.astype(np.float32)

print(f"Computing SHAP values for {len(exp_meta)} rows "
      f"(nsamples={SHAP_NSAMPLES}) — this may take a few minutes…")
shap_vals = explainer.shap_values(
    exp_meta,
    nsamples=SHAP_NSAMPLES,
    silent=False,           # show progress bar
)
# shap_vals shape: (n_explain, n_features)
print(f"  Done. shap_vals shape: {np.array(shap_vals).shape}")

# ─── 8. Aggregate: mean absolute SHAP per feature ─────────────────────────────
mean_abs = np.abs(shap_vals).mean(axis=0)               # (n_features,)
order    = np.argsort(mean_abs)[::-1][:SHAP_TOP_K]      # top-k descending

# ─── 9. Bar chart — mean |SHAP| ───────────────────────────────────────────────
top_k     = min(SHAP_TOP_K, len(meta_cols))
top_vals  = mean_abs[order][::-1]
top_names = [meta_cols[i] for i in order][::-1]

fig, ax = plt.subplots(figsize=(10, 8))
ax.barh(range(top_k), top_vals, color="#4393c3")
ax.set_yticks(range(top_k))
ax.set_yticklabels(top_names, fontsize=9)
ax.set_xlabel("Mean |SHAP value|  (average impact on P(Melanoma))")
ax.set_title(
    f"SHAP — Global Clinical Feature Importance\n"
    f"(KernelExplainer, n={len(exp_meta)} val samples, "
    f"background={SHAP_BACKGROUND})",
    fontsize=12, fontweight="bold"
)
ax.grid(axis="x", alpha=0.3)
plt.tight_layout()
_save_fig(fig, "xai_shap_bar.png")

# ─── 10. Beeswarm summary plot ────────────────────────────────────────────────
try:
    plt.figure(figsize=(10, 8))
    shap.summary_plot(
        shap_vals[:, order],
        features     = exp_meta[:, order],
        feature_names= [meta_cols[i] for i in order],
        show         = False,
        max_display  = top_k,
        plot_size    = None,
    )
    plt.title(
        "SHAP Beeswarm — Clinical Feature Impact on P(Melanoma)",
        fontsize=12, fontweight="bold"
    )
    plt.tight_layout()
    _save_fig(plt.gcf(), "xai_shap_beeswarm.png")
except Exception as e:
    print(f"  Beeswarm skipped: {e}")

# ─── 11. Save CSV ─────────────────────────────────────────────────────────────
shap_df = pd.DataFrame({
    "feature":       meta_cols,
    "mean_abs_shap": mean_abs,
}).sort_values("mean_abs_shap", ascending=False)

csv_path = os.path.join(OUTPUT_DIR, "xai_shap_importance.csv")
shap_df.to_csv(csv_path, index=False)
print(f"\n  ✔ SHAP importance CSV → {csv_path}")
print(f"\n  Top 10 features by |SHAP|:")
print(shap_df.head(10).to_string(index=False))

# ─── 12. Cleanup ──────────────────────────────────────────────────────────────
gc.collect()
if DEVICE == "cuda":
    torch.cuda.empty_cache()

print(f"\n✅ SHAP analysis complete. All outputs in: {OUTPUT_DIR}")
# Out:
# Loading checkpoint: /kaggle/working/efficient_v2_outputs/best_efficient_v2_model.pth
#   meta_dim  : 23
#   threshold : 0.479
#   features  : ['age_scaled', 'melanocytic', 'sex_Unknown', 'sex_female', 'sex_male'] … (23 total)
#   EfficientNetV2-S feature map: 1280×12×12 → 144 spatial tokens
#   Model loaded ✔
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_55/1382973455.py in <cell line: 0>()
#      90 val_df_candidates = sorted(glob.glob(os.path.join(OUTPUT_DIR, "val_df*.csv")))
#      91 if not val_df_candidates:
# ---> 92     raise FileNotFoundError(
#      93         f"val_df.csv not found in {OUTPUT_DIR}. "
#      94         "Make sure Cell 1 finished successfully."
#
# FileNotFoundError: val_df.csv not found in /kaggle/working/efficient_v2_outputs/. Make sure Cell 1 finished successfully.
